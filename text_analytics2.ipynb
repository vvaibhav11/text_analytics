# %% [markdown]
# # Topic Modeling

# %%
import pandas as pd
import numpy as np
import gensim
import re
# Out:
# C:\Users\rebeccamukena\anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %% [markdown]
# ### 1. Data Pre-Processing

# %%
df = pd.read_csv('AirCanada_review_raw.csv')
df = df.drop(df.columns[0], axis=1)
df.head()
# Out:
#                                     title              user     user_type  \
# 0  24 hour delay which was not acceptable       Tony Harris  TripVerified
# 1                      Worst airline ever           S Deane  TripVerified
# 2           the staff had no power to act  Collins Mazraani  TripVerified
# 3            Absolutely the worst airline      Shawn Holden   NotVerified
# 4        I was not reimbursed for charges          G Ragami  TripVerified
#
#                                               review       publish_date  \
# 0    Flight from Sydney to Montreal cancelled on ...  6th February 2022
# 1    Air Canada’s website booked me with another ...  3rd February 2022
# 2    I had booked business class for my mother an...  27th January 2022
# 3   Houston to Prince George. They cancelled my f...  25th January 2022
# 4    Air Canada cancelled my flights twice so I h...  18th January 2022
#
#   Type Of Traveller      Seat Type                                   Route  \
# 0          Business  Economy Class                    Toronto to Vancouver
# 1      Solo Leisure  Economy Class  Tokyo to Seattle via Seoul / Vancouver
# 2    Family Leisure  Economy Class                     London to Montreal
# 3    Family Leisure  Economy Class                Houston to Prince George
# 4      Solo Leisure  Economy Class       Saskatoon to Chicago via Toronto
#
#       Date Flown  Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 0  February 2022             1                    1                 0
# 1  February 2022             0                    0                 0
# 2   January 2022             2                    3                 1
# 3  February 2021             1                    1                 0
# 4  December 2021             2                    2                 2
#
#    Inflight Entertainment  Ground Service  Wifi & Connectivity  \
# 0                       0               1                    0
# 1                       0               0                    0
# 2                       2               1                    4
# 3                       0               1                    0
# 4                       0               1                    0
#
#    Value For Money  page
# 0                1     1
# 1                1     1
# 2                2     1
# 3                1     1
# 4                1     1

# %%
df.columns
# Out:
# Index(['title', 'user', 'user_type', 'review', 'publish_date',
#        'Type Of Traveller', 'Seat Type', 'Route', 'Date Flown', 'Seat Comfort',
#        'Cabin Staff Service', 'Food & Beverages', 'Inflight Entertainment',
#        'Ground Service', 'Wifi & Connectivity', 'Value For Money', 'page'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1644 entries, 0 to 1643
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   title                   1644 non-null   object
#  1   user                    1644 non-null   object
#  2   user_type               1644 non-null   object
#  3   review                  1644 non-null   object
#  4   publish_date            1644 non-null   object
#  5   Type Of Traveller       1205 non-null   object
#  6   Seat Type               1644 non-null   object
#  7   Route                   1201 non-null   object
#  8   Date Flown              1202 non-null   object
#  9   Seat Comfort            1644 non-null   int64
#  10  Cabin Staff Service     1644 non-null   int64
#  11  Food & Beverages        1644 non-null   int64
#  12  Inflight Entertainment  1644 non-null   int64
#  13  Ground Service          1644 non-null   int64
#  14  Wifi & Connectivity     1644 non-null   int64
#  15  Value For Money         1644 non-null   int64
#  16  page                    1644 non-null   int64
# dtypes: int64(8), object(9)
# memory usage: 218.5+ KB

# %%
df['user_type'].value_counts()
# Out:
# Not Verified                        693
# TripVerified                        579
# VerifiedReview                      255
# NotVerified                         116
# TorontotoClevelandVerifiedReview      1
# Name: user_type, dtype: int64

# %%
df['Type Of Traveller'].value_counts()
# Out:
# Solo Leisure      444
# Couple Leisure    292
# Family Leisure    243
# Business          226
# Name: Type Of Traveller, dtype: int64

# %%
df['Seat Type'].value_counts()
# Out:
# Economy Class      1286
# Business Class      262
# Premium Economy      83
# First Class          13
# Name: Seat Type, dtype: int64

# %%
df['month_flown'] = df['Date Flown'].apply(lambda x: str(x).split()[0] if str(x).split()[0] != 'nan' else np.NaN)
df['year_flown'] = df['Date Flown'].apply(lambda x: str(x).split()[1] if len(str(x).split()) > 1 else np.NaN)

print(df['month_flown'].head())
print(df['year_flown'].head())
# Out:
# 0    February
# 1    February
# 2     January
# 3    February
# 4    December
# Name: month_flown, dtype: object
# 0    2022
# 1    2022
# 2    2022
# 3    2021
# 4    2021
# Name: year_flown, dtype: object

# %%
df['month_flown'].value_counts()
# Out:
# July         144
# August       134
# December     126
# September    106
# October      103
# January      102
# February      95
# November      93
# June          93
# March         74
# May           67
# April         65
# Name: month_flown, dtype: int64

# %%
df['year_flown'].value_counts()
# Out:
# 2019    255
# 2018    239
# 2016    187
# 2017    183
# 2015    162
# 2020     96
# 2021     68
# 2022      9
# 2014      3
# Name: year_flown, dtype: int64

# %%
# Remove punctuation
df['title_processed'] = df['title'].map(lambda x: re.sub('[,\.!?]', '', x))
df['review_processed'] = df['review'].map(lambda x: re.sub('[,\.!?]', '', x))

# Convert the titles to lowercase
df['title_processed'] = df['title_processed'].map(lambda x: x.lower())
df['review_processed'] = df['review_processed'].map(lambda x: x.lower())

print(df['title_processed'].head())
df['review_processed'].head()
# Out:
# 0    24 hour delay which was not acceptable
# 1                        worst airline ever
# 2             the staff had no power to act
# 3              absolutely the worst airline
# 4          i was not reimbursed for charges
# Name: title_processed, dtype: object
# 0      flight from sydney to montreal cancelled on ...
# 1      air canada’s website booked me with another ...
# 2      i had booked business class for my mother an...
# 3     houston to prince george they cancelled my fl...
# 4      air canada cancelled my flights twice so i h...
# Name: review_processed, dtype: object

# %% [markdown]
# ### 2. Data Exploration

# %%
from wordcloud import WordCloud
import gensim
from gensim.utils import simple_preprocess
import nltk
from nltk.corpus import stopwords
import gensim.corpora as corpora
from pprint import pprint

# %%
# Wordcloud
title_string = ','.join(list(df['title_processed'].values))
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')

wordcloud.generate(title_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x2552288A580>

# %%
# filter out a few words
sw = ['canada', 'air', 'customer', 'review', 'service', 'flight']
for w in sw:
    title_string = title_string.replace(w, "")

wordcloud.generate(title_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x25524D86850>

# %%
review_string = ','.join(list(df['review_processed'].values))
wordcloud.generate(review_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x2552288A220>

# %%
sw.append('toronto')
for w in sw:
    review_string = review_string.replace(w, "")

wordcloud.generate(review_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x25524D867C0>

# %% [markdown]
# ### Analysis and Insights
#
# The wordclouds show there are all kinds of themes in these reviews (delays, food, customer service, good and bad experiences). Our next setp would be to identify the main topics. In addition, we can observe that there are a few additional stopwords to remove before we proceed.

# %% [markdown]
# ### 3. Topic Selection

# %% [markdown]
# ### 3.1 Document Topic Modeling

# %%
stop_words = stopwords.words('english')
stop_words.extend(['canada', 'air', 'customer', 'review', 'service', 'flight', 'toronto', 'one', 'would', 's', 'us', 
                   'could'])

def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True)) # deacc=True removes punctuations

def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) 
             if word not in stop_words] for doc in texts]

# %%
def topic_generator(dfcol, num_topics):
    data = dfcol.values.tolist()
    data_words = list(sent_to_words(data))
    data_words = remove_stopwords(data_words)
    # print(data_words[:1][0][:30])

    id2word = corpora.Dictionary(data_words)
    texts = data_words
    corpus = [id2word.doc2bow(text) for text in texts]
    # print(corpus[:1][0][:30])

    lda_model = gensim.models.LdaMulticore(corpus=corpus, id2word=id2word, num_topics=num_topics)
    pprint(lda_model.print_topics())
    doc_lda = lda_model[corpus]

# %%
# TOPICS FROM REVIEWS
topic_generator(df.review_processed, 5)
# Out:
# [(0,
#   '0.009*"time" + 0.005*"got" + 0.005*"staff" + 0.005*"ac" + 0.005*"gate" + '
#   '0.005*"vancouver" + 0.005*"good" + 0.005*"seat" + 0.005*"flights" + '
#   '0.005*"check"'),
#  (1,
#   '0.008*"get" + 0.008*"time" + 0.007*"seat" + 0.006*"hours" + 0.006*"ac" + '
#   '0.005*"plane" + 0.005*"luggage" + 0.005*"vancouver" + 0.005*"airport" + '
#   '0.005*"flights"'),
#  (2,
#   '0.008*"time" + 0.007*"hours" + 0.007*"vancouver" + 0.006*"seats" + '
#   '0.006*"food" + 0.006*"ac" + 0.006*"back" + 0.006*"good" + 0.006*"delayed" + '
#   '0.005*"flights"'),
#  (3,
#   '0.007*"time" + 0.007*"flights" + 0.007*"ac" + 0.007*"seat" + 0.006*"staff" '
#   '+ 0.006*"food" + 0.005*"even" + 0.005*"airline" + 0.005*"crew" + '
#   '0.005*"good"'),
#  (4,
#   '0.009*"time" + 0.008*"seat" + 0.007*"flights" + 0.006*"seats" + '
#   '0.006*"staff" + 0.006*"plane" + 0.006*"crew" + 0.006*"get" + 0.006*"good" + '
#   '0.005*"class"')]

# %% [markdown]
# ### Analysis and Insights
#
# It is hard to derive the true insights from the reviews as word proportions are very low. Let's try with the reviews titles as they are more concise.

# %%
# TOPIC FROM TITLES
topic_generator(df.title_processed, 4)
# Out:
# [(0,
#   '0.023*"crew" + 0.018*"cabin" + 0.018*"hours" + 0.015*"good" + '
#   '0.012*"disappointed" + 0.011*"friendly" + 0.010*"food" + 0.008*"delayed" + '
#   '0.008*"luggage" + 0.008*"get"'),
#  (1,
#   '0.039*"experience" + 0.025*"good" + 0.021*"staff" + 0.013*"attendants" + '
#   '0.011*"pleasant" + 0.011*"seats" + 0.010*"luggage" + 0.010*"comfortable" + '
#   '0.009*"never" + 0.009*"overall"'),
#  (2,
#   '0.026*"delayed" + 0.018*"seat" + 0.018*"cancelled" + 0.014*"airline" + '
#   '0.014*"uncomfortable" + 0.013*"time" + 0.010*"flights" + 0.010*"hour" + '
#   '0.010*"extremely" + 0.010*"helpful"'),
#  (3,
#   '0.026*"worst" + 0.020*"experience" + 0.018*"terrible" + 0.018*"airline" + '
#   '0.016*"staff" + 0.016*"excellent" + 0.015*"food" + 0.013*"class" + '
#   '0.011*"poor" + 0.011*"good"')]

# %% [markdown]
# ### Analysis and Insights
#
# Topics:
# - 0: good experience: good crew and cabin, although there might be delays
# - 1: great experience: good experience with staff and crew overall
# - 2: bad experience: delays, cancellations and uncomfortable seats
# - 3: mixed experience: terrible experience but the staff and food were excellent
#
# Overall, the staff, crew and cabin are doing a great job and the customers recognize and appreciate their efforts despite the difficulties that they moght face during their experience with Air Canada.

# %% [markdown]
# ### 3.2 Topics by Customer Segments

# %%
# topics by user types
for user in df.user_type.unique():
    temp_df = df.loc[df['user_type'] == user]
    print(user, ":")
    topic_generator(temp_df, 5)
    print('\n')
# Out:
# TripVerified :
# [(0,
#   '0.012*"time" + 0.010*"vancouver" + 0.010*"class" + 0.008*"economy" + '
#   '0.007*"tripverified" + 0.007*"hours" + 0.007*"get" + 0.007*"seat" + '
#   '0.006*"th" + 0.006*"good"'),
#  (1,
#   '0.010*"economy" + 0.008*"airline" + 0.008*"class" + 0.007*"hours" + '
#   '0.006*"montreal" + 0.006*"time" + 0.006*"tripverified" + 0.006*"leisure" + '
#   '0.005*"flights" + 0.005*"plane"'),
#  (2,
#   '0.011*"class" + 0.008*"time" + 0.008*"economy" + 0.007*"vancouver" + '
#   '0.007*"business" + 0.007*"staff" + 0.007*"get" + 0.007*"flights" + '
#   '0.007*"hours" + 0.006*"tripverified"'),
#  (3,
#   '0.008*"vancouver" + 0.007*"economy" + 0.007*"delayed" + 0.007*"hours" + '
#   '0.007*"class" + 0.007*"get" + 0.007*"tripverified" + 0.007*"time" + '
#   '0.006*"told" + 0.006*"th"'),
#  (4,
#   '0.007*"economy" + 0.007*"class" + 0.006*"time" + 0.006*"get" + '
#   '0.006*"seats" + 0.005*"hour" + 0.005*"fly" + 0.005*"tripverified" + '
#   '0.005*"hours" + 0.005*"vancouver"')]
#
#
# NotVerified :
# [(0,
#   '0.008*"economy" + 0.007*"class" + 0.007*"th" + 0.007*"vancouver" + '
#   '0.007*"notverified" + 0.006*"airline" + 0.006*"get" + 0.006*"flights" + '
#   '0.006*"time" + 0.006*"good"'),
#  (1,
#   '0.007*"time" + 0.007*"flights" + 0.007*"class" + 0.007*"economy" + '
#   '0.006*"th" + 0.006*"notverified" + 0.006*"leisure" + 0.006*"credit" + '
#   '0.005*"staff" + 0.005*"due"'),
#  (2,
#   '0.008*"staff" + 0.007*"economy" + 0.007*"time" + 0.007*"class" + '
#   '0.007*"montreal" + 0.006*"hour" + 0.006*"th" + 0.006*"passengers" + '
#   '0.006*"good" + 0.006*"notverified"'),
#  (3,
#   '0.012*"time" + 0.009*"flights" + 0.008*"class" + 0.008*"th" + 0.008*"staff" '
#   '+ 0.007*"notverified" + 0.006*"economy" + 0.006*"ac" + 0.005*"leisure" + '
#   '0.005*"told"'),
#  (4,
#   '0.008*"get" + 0.008*"time" + 0.007*"class" + 0.006*"airport" + 0.006*"th" + '
#   '0.006*"told" + 0.006*"notverified" + 0.006*"economy" + 0.006*"boarding" + '
#   '0.005*"went"')]
#
#
# Not Verified :
# [(0,
#   '0.028*"nan" + 0.012*"class" + 0.009*"ac" + 0.009*"economy" + 0.008*"crew" + '
#   '0.008*"th" + 0.008*"verified" + 0.007*"food" + 0.007*"good" + '
#   '0.007*"seats"'),
#  (1,
#   '0.009*"nan" + 0.009*"class" + 0.008*"seat" + 0.007*"business" + '
#   '0.007*"economy" + 0.007*"seats" + 0.006*"plane" + 0.006*"food" + '
#   '0.006*"time" + 0.005*"th"'),
#  (2,
#   '0.023*"nan" + 0.011*"class" + 0.009*"economy" + 0.008*"time" + 0.008*"seat" '
#   '+ 0.008*"ac" + 0.007*"food" + 0.007*"seats" + 0.007*"staff" + '
#   '0.007*"flights"'),
#  (3,
#   '0.012*"nan" + 0.010*"economy" + 0.010*"class" + 0.008*"seat" + 0.008*"time" '
#   '+ 0.007*"seats" + 0.006*"business" + 0.006*"flights" + 0.005*"food" + '
#   '0.005*"verified"'),
#  (4,
#   '0.015*"nan" + 0.012*"ac" + 0.009*"economy" + 0.008*"good" + 0.008*"class" + '
#   '0.007*"food" + 0.007*"time" + 0.006*"verified" + 0.006*"th" + '
#   '0.006*"seats"')]
#
#
# VerifiedReview :
# [(0,
#   '0.008*"economy" + 0.007*"flights" + 0.007*"class" + 0.007*"seat" + '
#   '0.006*"time" + 0.006*"good" + 0.006*"ac" + 0.006*"th" + '
#   '0.005*"verifiedreview" + 0.005*"staff"'),
#  (1,
#   '0.011*"class" + 0.009*"economy" + 0.008*"business" + 0.007*"time" + '
#   '0.006*"food" + 0.006*"good" + 0.006*"cabin" + 0.006*"staff" + '
#   '0.006*"verifiedreview" + 0.005*"via"'),
#  (2,
#   '0.009*"economy" + 0.007*"class" + 0.007*"staff" + 0.007*"time" + '
#   '0.006*"seat" + 0.006*"airport" + 0.006*"get" + 0.006*"airline" + '
#   '0.006*"flights" + 0.005*"seats"'),
#  (3,
#   '0.011*"time" + 0.008*"class" + 0.008*"business" + 0.008*"economy" + '
#   '0.007*"vancouver" + 0.007*"flights" + 0.007*"good" + 0.006*"get" + '
#   '0.006*"seat" + 0.006*"airport"'),
#  (4,
#   '0.008*"class" + 0.007*"time" + 0.006*"via" + 0.006*"hours" + '
#   '0.005*"airline" + 0.005*"verifiedreview" + 0.005*"business" + '
#   '0.005*"vancouver" + 0.005*"get" + 0.005*"flights"')]
#
#
# TorontotoClevelandVerifiedReview :
# [(0,
#   '0.046*"airline" + 0.029*"stories" + 0.028*"heard" + 0.027*"delays" + '
#   '0.027*"avoided" + 0.026*"pilot" + 0.024*"flights" + 0.023*"changing" + '
#   '0.023*"worst" + 0.022*"july"'),
#  (1,
#   '0.065*"airline" + 0.033*"heard" + 0.032*"worst" + 0.031*"flights" + '
#   '0.030*"stories" + 0.028*"avoided" + 0.028*"pilot" + 0.027*"delays" + '
#   '0.026*"changing" + 0.022*"july"'),
#  (2,
#   '0.047*"airline" + 0.029*"pilot" + 0.029*"flights" + 0.027*"worst" + '
#   '0.027*"delays" + 0.026*"avoided" + 0.026*"stories" + 0.023*"changing" + '
#   '0.023*"heard" + 0.023*"july"'),
#  (3,
#   '0.044*"airline" + 0.035*"delays" + 0.031*"avoided" + 0.030*"stories" + '
#   '0.028*"heard" + 0.027*"flights" + 0.025*"july" + 0.024*"pilot" + '
#   '0.023*"worst" + 0.021*"changing"'),
#  (4,
#   '0.047*"airline" + 0.035*"pilot" + 0.033*"worst" + 0.031*"avoided" + '
#   '0.031*"flights" + 0.028*"stories" + 0.028*"delays" + 0.027*"heard" + '
#   '0.024*"july" + 0.020*"changing"')]

# %%
# topics by type of traveller
for tot in df['Type Of Traveller'].unique()[0:4]:
    temp_df = df.loc[df['Type Of Traveller'] == tot]
    print(tot, ":")
    topic_generator(temp_df, 5)
    print('\n')
# Out:
# Business :
# [(0,
#   '0.013*"time" + 0.009*"business" + 0.007*"hours" + 0.007*"plane" + '
#   '0.007*"hour" + 0.006*"montreal" + 0.006*"class" + 0.006*"airport" + '
#   '0.005*"crew" + 0.005*"via"'),
#  (1,
#   '0.012*"business" + 0.011*"class" + 0.009*"time" + 0.007*"hours" + '
#   '0.006*"staff" + 0.006*"economy" + 0.006*"check" + 0.006*"airline" + '
#   '0.006*"seat" + 0.005*"agent"'),
#  (2,
#   '0.016*"business" + 0.012*"class" + 0.009*"time" + 0.008*"good" + '
#   '0.007*"economy" + 0.007*"staff" + 0.006*"montreal" + 0.006*"hours" + '
#   '0.006*"th" + 0.006*"airline"'),
#  (3,
#   '0.015*"business" + 0.013*"class" + 0.009*"economy" + 0.008*"time" + '
#   '0.007*"vancouver" + 0.006*"hours" + 0.006*"food" + 0.006*"staff" + '
#   '0.006*"flights" + 0.005*"plane"'),
#  (4,
#   '0.013*"business" + 0.009*"time" + 0.008*"class" + 0.007*"hours" + '
#   '0.006*"delayed" + 0.006*"th" + 0.006*"ac" + 0.006*"experience" + '
#   '0.006*"flights" + 0.006*"airline"')]
#
#
# Solo Leisure :
# [(0,
#   '0.012*"time" + 0.010*"economy" + 0.008*"class" + 0.007*"flights" + '
#   '0.007*"seat" + 0.007*"food" + 0.006*"solo" + 0.006*"leisure" + 0.006*"get" '
#   '+ 0.005*"th"'),
#  (1,
#   '0.009*"vancouver" + 0.009*"flights" + 0.008*"time" + 0.007*"class" + '
#   '0.006*"solo" + 0.006*"th" + 0.006*"plane" + 0.006*"good" + 0.006*"economy" '
#   '+ 0.006*"leisure"'),
#  (2,
#   '0.009*"class" + 0.009*"economy" + 0.008*"hours" + 0.007*"th" + '
#   '0.006*"airline" + 0.006*"solo" + 0.006*"leisure" + 0.006*"get" + '
#   '0.006*"vancouver" + 0.006*"flights"'),
#  (3,
#   '0.009*"class" + 0.008*"seat" + 0.007*"economy" + 0.007*"get" + '
#   '0.006*"leisure" + 0.006*"solo" + 0.006*"delayed" + 0.005*"time" + '
#   '0.005*"th" + 0.005*"airline"'),
#  (4,
#   '0.011*"class" + 0.011*"economy" + 0.007*"seat" + 0.007*"time" + '
#   '0.007*"leisure" + 0.006*"flights" + 0.006*"vancouver" + 0.006*"solo" + '
#   '0.005*"th" + 0.005*"staff"')]
#
#
# Family Leisure :
# [(0,
#   '0.012*"class" + 0.009*"family" + 0.009*"economy" + 0.008*"good" + '
#   '0.007*"time" + 0.007*"seat" + 0.006*"vancouver" + 0.006*"hours" + '
#   '0.006*"th" + 0.006*"staff"'),
#  (1,
#   '0.013*"seats" + 0.010*"economy" + 0.009*"staff" + 0.009*"family" + '
#   '0.009*"plane" + 0.008*"leisure" + 0.007*"class" + 0.007*"get" + 0.006*"th" '
#   '+ 0.006*"montreal"'),
#  (2,
#   '0.010*"economy" + 0.008*"family" + 0.008*"vancouver" + 0.007*"food" + '
#   '0.006*"class" + 0.006*"via" + 0.006*"th" + 0.006*"staff" + 0.006*"leisure" '
#   '+ 0.006*"get"'),
#  (3,
#   '0.008*"get" + 0.008*"hours" + 0.008*"vancouver" + 0.007*"economy" + '
#   '0.007*"family" + 0.007*"luggage" + 0.006*"via" + 0.006*"delayed" + '
#   '0.006*"airport" + 0.006*"staff"'),
#  (4,
#   '0.008*"class" + 0.007*"family" + 0.007*"leisure" + 0.007*"economy" + '
#   '0.006*"time" + 0.006*"staff" + 0.006*"delayed" + 0.006*"montreal" + '
#   '0.005*"good" + 0.005*"passengers"')]
#
#
# Couple Leisure :
# [(0,
#   '0.009*"time" + 0.009*"economy" + 0.007*"vancouver" + 0.007*"class" + '
#   '0.006*"couple" + 0.005*"get" + 0.005*"seats" + 0.005*"leisure" + '
#   '0.005*"food" + 0.005*"meal"'),
#  (1,
#   '0.009*"time" + 0.009*"class" + 0.008*"economy" + 0.007*"couple" + '
#   '0.007*"good" + 0.007*"seats" + 0.007*"told" + 0.006*"seat" + '
#   '0.006*"vancouver" + 0.006*"leisure"'),
#  (2,
#   '0.010*"economy" + 0.008*"class" + 0.008*"flights" + 0.007*"time" + '
#   '0.007*"back" + 0.007*"get" + 0.006*"staff" + 0.006*"told" + 0.006*"leisure" '
#   '+ 0.006*"couple"'),
#  (3,
#   '0.009*"get" + 0.009*"seat" + 0.006*"time" + 0.006*"class" + 0.006*"plane" + '
#   '0.006*"economy" + 0.006*"couple" + 0.005*"vancouver" + 0.005*"staff" + '
#   '0.005*"flights"'),
#  (4,
#   '0.008*"time" + 0.007*"vancouver" + 0.007*"economy" + 0.006*"got" + '
#   '0.006*"staff" + 0.006*"get" + 0.006*"class" + 0.006*"couple" + '
#   '0.006*"leisure" + 0.005*"seats"')]

# %%
# topics by seat types
for seat in df['Seat Type'].unique():
    temp_df = df.loc[df['Seat Type'] == seat]
    print(seat, ":")
    topic_generator(temp_df, 5)
    print('\n')
# Out:
# Economy Class :
# [(0,
#   '0.010*"economy" + 0.008*"class" + 0.008*"nan" + 0.007*"th" + 0.006*"hours" '
#   '+ 0.006*"ac" + 0.006*"crew" + 0.006*"flights" + 0.006*"food" + '
#   '0.006*"vancouver"'),
#  (1,
#   '0.010*"time" + 0.009*"economy" + 0.008*"class" + 0.008*"hours" + '
#   '0.007*"told" + 0.007*"staff" + 0.007*"get" + 0.007*"nan" + 0.006*"hour" + '
#   '0.006*"airline"'),
#  (2,
#   '0.012*"nan" + 0.010*"time" + 0.009*"economy" + 0.007*"class" + '
#   '0.007*"flights" + 0.007*"th" + 0.007*"get" + 0.007*"vancouver" + '
#   '0.006*"good" + 0.005*"ac"'),
#  (3,
#   '0.009*"economy" + 0.008*"seat" + 0.008*"plane" + 0.008*"class" + '
#   '0.007*"flights" + 0.007*"time" + 0.006*"staff" + 0.006*"vancouver" + '
#   '0.006*"get" + 0.005*"nan"'),
#  (4,
#   '0.011*"nan" + 0.008*"time" + 0.007*"th" + 0.007*"hours" + 0.007*"class" + '
#   '0.006*"seats" + 0.006*"flights" + 0.006*"food" + 0.006*"economy" + '
#   '0.005*"back"')]
#
#
# Premium Economy :
# [(0,
#   '0.014*"premium" + 0.014*"economy" + 0.010*"flights" + 0.007*"seats" + '
#   '0.007*"passengers" + 0.006*"cabin" + 0.006*"good" + 0.005*"food" + '
#   '0.005*"time" + 0.005*"meal"'),
#  (1,
#   '0.020*"premium" + 0.015*"economy" + 0.011*"seats" + 0.007*"time" + '
#   '0.007*"staff" + 0.006*"seat" + 0.005*"back" + 0.005*"good" + 0.005*"plane" '
#   '+ 0.005*"get"'),
#  (2,
#   '0.016*"economy" + 0.013*"premium" + 0.006*"good" + 0.006*"back" + '
#   '0.005*"seats" + 0.005*"montreal" + 0.005*"even" + 0.005*"food" + '
#   '0.005*"told" + 0.005*"seat"'),
#  (3,
#   '0.018*"premium" + 0.016*"economy" + 0.007*"seats" + 0.007*"time" + '
#   '0.006*"montreal" + 0.006*"seat" + 0.006*"hours" + 0.005*"vancouver" + '
#   '0.005*"food" + 0.005*"even"'),
#  (4,
#   '0.029*"economy" + 0.020*"premium" + 0.009*"seats" + 0.009*"vancouver" + '
#   '0.008*"good" + 0.008*"time" + 0.006*"meal" + 0.006*"food" + 0.006*"cabin" + '
#   '0.006*"th"')]
#
#
# Business Class :
# [(0,
#   '0.020*"class" + 0.017*"business" + 0.012*"good" + 0.011*"nan" + 0.007*"ac" '
#   '+ 0.007*"seat" + 0.007*"food" + 0.006*"time" + 0.006*"th" + 0.006*"seats"'),
#  (1,
#   '0.015*"business" + 0.012*"class" + 0.007*"good" + 0.007*"food" + 0.007*"ac" '
#   '+ 0.006*"time" + 0.005*"flights" + 0.005*"experience" + 0.005*"seat" + '
#   '0.004*"via"'),
#  (2,
#   '0.023*"business" + 0.021*"class" + 0.012*"seat" + 0.011*"nan" + '
#   '0.007*"crew" + 0.007*"good" + 0.006*"food" + 0.006*"ac" + 0.005*"new" + '
#   '0.005*"seats"'),
#  (3,
#   '0.027*"business" + 0.023*"class" + 0.010*"nan" + 0.009*"food" + '
#   '0.008*"seat" + 0.007*"seats" + 0.007*"good" + 0.007*"ac" + 0.006*"cabin" + '
#   '0.005*"excellent"'),
#  (4,
#   '0.015*"business" + 0.015*"class" + 0.013*"ac" + 0.010*"nan" + 0.010*"good" '
#   '+ 0.009*"seat" + 0.008*"time" + 0.007*"yyz" + 0.006*"food" + 0.006*"staff"')]
#
#
# First Class :
# [(0,
#   '0.015*"class" + 0.012*"economy" + 0.010*"first" + 0.009*"good" + '
#   '0.009*"back" + 0.008*"really" + 0.008*"ac" + 0.007*"seat" + 0.007*"flights" '
#   '+ 0.006*"trip"'),
#  (1,
#   '0.015*"first" + 0.014*"class" + 0.012*"trip" + 0.010*"montreal" + '
#   '0.009*"economy" + 0.008*"row" + 0.008*"seats" + 0.008*"ac" + 0.007*"way" + '
#   '0.007*"leg"'),
#  (2,
#   '0.018*"first" + 0.014*"nan" + 0.012*"good" + 0.011*"economy" + '
#   '0.011*"class" + 0.010*"seat" + 0.009*"trip" + 0.009*"ac" + 0.009*"way" + '
#   '0.008*"cabin"'),
#  (3,
#   '0.014*"first" + 0.013*"class" + 0.013*"nan" + 0.011*"seats" + '
#   '0.011*"really" + 0.010*"trip" + 0.010*"economy" + 0.010*"route" + '
#   '0.009*"delhi" + 0.009*"ac"'),
#  (4,
#   '0.016*"nan" + 0.015*"first" + 0.013*"class" + 0.011*"good" + 0.009*"trip" + '
#   '0.008*"great" + 0.007*"vancouver" + 0.007*"flights" + 0.007*"seats" + '
#   '0.007*"dulles"')]

# %%
# topics by year
for year in df['year_flown'].unique():
    temp_df = df.loc[df['year_flown'] == year]
    print(year, ":")
    topic_generator(temp_df, 5)
    print('\n')
# Out:
# 2022 :
# [(0,
#   '0.021*"airline" + 0.013*"never" + 0.012*"ever" + 0.011*"de" + '
#   '0.011*"booked" + 0.008*"business" + 0.008*"la" + 0.008*"le" + '
#   '0.007*"february" + 0.007*"flown"'),
#  (1,
#   '0.013*"january" + 0.012*"got" + 0.011*"vancouver" + 0.010*"back" + '
#   '0.010*"hour" + 0.009*"montreal" + 0.009*"business" + 0.009*"hours" + '
#   '0.009*"min" + 0.008*"plane"'),
#  (2,
#   '0.014*"de" + 0.012*"montreal" + 0.012*"january" + 0.010*"le" + '
#   '0.009*"business" + 0.009*"la" + 0.008*"hour" + 0.007*"plane" + 0.006*"et" + '
#   '0.006*"airline"'),
#  (3,
#   '0.014*"baggage" + 0.013*"delayed" + 0.010*"hour" + 0.010*"montreal" + '
#   '0.009*"connecting" + 0.008*"business" + 0.008*"de" + 0.007*"got" + '
#   '0.007*"la" + 0.007*"told"'),
#  (4,
#   '0.022*"de" + 0.014*"business" + 0.013*"la" + 0.010*"le" + 0.008*"ils" + '
#   '0.007*"pour" + 0.007*"montreal" + 0.007*"et" + 0.007*"mother" + 0.007*"qu"')]
#
#
# 2021 :
# [(0,
#   '0.009*"class" + 0.009*"told" + 0.009*"hour" + 0.008*"luggage" + '
#   '0.007*"back" + 0.007*"business" + 0.007*"flights" + 0.006*"th" + '
#   '0.006*"august" + 0.006*"airline"'),
#  (1,
#   '0.010*"class" + 0.007*"get" + 0.007*"delayed" + 0.007*"back" + '
#   '0.007*"economy" + 0.006*"flights" + 0.006*"time" + 0.006*"airport" + '
#   '0.006*"th" + 0.006*"line"'),
#  (2,
#   '0.011*"time" + 0.010*"told" + 0.008*"class" + 0.008*"good" + 0.008*"th" + '
#   '0.008*"airport" + 0.007*"staff" + 0.006*"august" + 0.006*"economy" + '
#   '0.006*"line"'),
#  (3,
#   '0.011*"class" + 0.009*"time" + 0.008*"back" + 0.007*"get" + 0.007*"economy" '
#   '+ 0.007*"business" + 0.007*"th" + 0.006*"flights" + 0.006*"august" + '
#   '0.005*"leisure"'),
#  (4,
#   '0.010*"day" + 0.009*"august" + 0.009*"next" + 0.008*"luggage" + '
#   '0.008*"class" + 0.007*"economy" + 0.006*"hours" + 0.006*"told" + '
#   '0.005*"without" + 0.005*"th"')]
#
#
# 2020 :
# [(0,
#   '0.010*"time" + 0.007*"class" + 0.007*"due" + 0.007*"flights" + '
#   '0.006*"calgary" + 0.006*"economy" + 0.006*"th" + 0.006*"vancouver" + '
#   '0.005*"hours" + 0.005*"back"'),
#  (1,
#   '0.009*"class" + 0.008*"get" + 0.007*"th" + 0.007*"vancouver" + '
#   '0.007*"march" + 0.006*"economy" + 0.006*"ticket" + 0.006*"even" + '
#   '0.005*"flights" + 0.005*"experience"'),
#  (2,
#   '0.009*"economy" + 0.008*"seat" + 0.007*"class" + 0.006*"cancelled" + '
#   '0.006*"january" + 0.006*"flights" + 0.006*"leisure" + 0.006*"th" + '
#   '0.006*"due" + 0.006*"hours"'),
#  (3,
#   '0.009*"get" + 0.009*"credit" + 0.008*"due" + 0.007*"economy" + 0.007*"got" '
#   '+ 0.007*"fly" + 0.007*"cancelled" + 0.006*"january" + 0.006*"back" + '
#   '0.006*"th"'),
#  (4,
#   '0.008*"seats" + 0.008*"seat" + 0.007*"flights" + 0.007*"february" + '
#   '0.007*"class" + 0.006*"economy" + 0.006*"time" + 0.006*"leisure" + '
#   '0.006*"airline" + 0.006*"credit"')]
#
#
# 2019 :
# [(0,
#   '0.009*"vancouver" + 0.008*"get" + 0.008*"class" + 0.007*"economy" + '
#   '0.007*"time" + 0.007*"seat" + 0.006*"hours" + 0.006*"staff" + '
#   '0.006*"delayed" + 0.005*"told"'),
#  (1,
#   '0.010*"economy" + 0.009*"time" + 0.009*"class" + 0.008*"delayed" + '
#   '0.007*"hours" + 0.007*"get" + 0.007*"th" + 0.006*"flights" + 0.006*"check" '
#   '+ 0.006*"seat"'),
#  (2,
#   '0.011*"class" + 0.010*"get" + 0.009*"time" + 0.009*"hours" + '
#   '0.008*"economy" + 0.007*"airport" + 0.007*"vancouver" + 0.007*"th" + '
#   '0.006*"staff" + 0.006*"tripverified"'),
#  (3,
#   '0.011*"class" + 0.010*"economy" + 0.009*"business" + 0.007*"flights" + '
#   '0.007*"th" + 0.006*"time" + 0.006*"seat" + 0.006*"vancouver" + '
#   '0.006*"hours" + 0.006*"seats"'),
#  (4,
#   '0.010*"time" + 0.007*"economy" + 0.006*"class" + 0.006*"get" + '
#   '0.005*"plane" + 0.005*"th" + 0.005*"hours" + 0.005*"via" + 0.005*"baggage" '
#   '+ 0.005*"vancouver"')]
#
#
# 2018 :
# [(0,
#   '0.009*"time" + 0.008*"get" + 0.008*"vancouver" + 0.007*"staff" + '
#   '0.007*"flights" + 0.006*"airport" + 0.006*"class" + 0.006*"economy" + '
#   '0.006*"told" + 0.006*"th"'),
#  (1,
#   '0.009*"economy" + 0.008*"get" + 0.007*"time" + 0.007*"staff" + '
#   '0.007*"class" + 0.007*"vancouver" + 0.006*"tripverified" + 0.006*"th" + '
#   '0.006*"montreal" + 0.006*"hours"'),
#  (2,
#   '0.008*"economy" + 0.007*"class" + 0.007*"airline" + 0.007*"plane" + '
#   '0.006*"seats" + 0.006*"time" + 0.006*"flights" + 0.006*"vancouver" + '
#   '0.006*"seat" + 0.006*"good"'),
#  (3,
#   '0.011*"vancouver" + 0.009*"time" + 0.009*"class" + 0.008*"hours" + '
#   '0.008*"economy" + 0.008*"via" + 0.007*"staff" + 0.007*"told" + '
#   '0.007*"delayed" + 0.006*"tripverified"'),
#  (4,
#   '0.009*"time" + 0.009*"class" + 0.008*"economy" + 0.007*"tripverified" + '
#   '0.006*"vancouver" + 0.006*"business" + 0.006*"boarding" + 0.006*"food" + '
#   '0.006*"via" + 0.005*"th"')]
#
#
# 2017 :
# [(0,
#   '0.009*"time" + 0.007*"ac" + 0.006*"delayed" + 0.006*"economy" + '
#   '0.006*"flights" + 0.006*"hours" + 0.005*"check" + 0.005*"experience" + '
#   '0.005*"good" + 0.004*"seats"'),
#  (1,
#   '0.009*"class" + 0.007*"vancouver" + 0.007*"economy" + 0.007*"flights" + '
#   '0.006*"time" + 0.006*"staff" + 0.005*"seat" + 0.005*"hour" + 0.005*"get" + '
#   '0.005*"th"'),
#  (2,
#   '0.010*"class" + 0.010*"business" + 0.007*"flights" + 0.007*"time" + '
#   '0.007*"economy" + 0.007*"airline" + 0.007*"via" + 0.006*"montreal" + '
#   '0.006*"good" + 0.005*"ac"'),
#  (3,
#   '0.009*"economy" + 0.008*"time" + 0.007*"staff" + 0.006*"flights" + '
#   '0.006*"class" + 0.006*"vancouver" + 0.005*"montreal" + 0.005*"via" + '
#   '0.005*"got" + 0.005*"th"'),
#  (4,
#   '0.008*"vancouver" + 0.007*"economy" + 0.007*"fly" + 0.007*"flights" + '
#   '0.007*"staff" + 0.006*"check" + 0.006*"time" + 0.006*"class" + '
#   '0.006*"luggage" + 0.006*"airport"')]
#
#
# 2016 :
# [(0,
#   '0.010*"time" + 0.009*"class" + 0.009*"economy" + 0.007*"good" + '
#   '0.006*"business" + 0.006*"seat" + 0.006*"flights" + 0.006*"crew" + '
#   '0.006*"food" + 0.006*"yyz"'),
#  (1,
#   '0.010*"economy" + 0.010*"time" + 0.007*"plane" + 0.007*"class" + '
#   '0.006*"flights" + 0.006*"th" + 0.006*"food" + 0.006*"airport" + '
#   '0.006*"hour" + 0.006*"hours"'),
#  (2,
#   '0.012*"time" + 0.010*"economy" + 0.008*"seat" + 0.007*"class" + '
#   '0.006*"staff" + 0.006*"good" + 0.006*"food" + 0.005*"plane" + 0.005*"get" + '
#   '0.005*"crew"'),
#  (3,
#   '0.009*"economy" + 0.007*"class" + 0.007*"seats" + 0.005*"seat" + '
#   '0.005*"experience" + 0.005*"via" + 0.005*"ac" + 0.005*"good" + '
#   '0.005*"flights" + 0.005*"get"'),
#  (4,
#   '0.012*"class" + 0.011*"good" + 0.010*"economy" + 0.008*"plane" + '
#   '0.008*"business" + 0.007*"cabin" + 0.007*"time" + 0.006*"crew" + '
#   '0.006*"food" + 0.006*"seat"')]
#
#
# 2015 :
# [(0,
#   '0.010*"class" + 0.008*"economy" + 0.007*"seat" + 0.006*"good" + '
#   '0.006*"leisure" + 0.006*"verified" + 0.006*"th" + 0.006*"time" + '
#   '0.005*"food" + 0.005*"luggage"'),
#  (1,
#   '0.010*"class" + 0.008*"food" + 0.008*"economy" + 0.008*"seats" + '
#   '0.007*"seat" + 0.006*"business" + 0.006*"verified" + 0.006*"staff" + '
#   '0.006*"th" + 0.005*"leisure"'),
#  (2,
#   '0.010*"seat" + 0.009*"good" + 0.008*"class" + 0.008*"economy" + '
#   '0.007*"seats" + 0.007*"business" + 0.006*"food" + 0.006*"time" + '
#   '0.005*"flights" + 0.005*"verified"'),
#  (3,
#   '0.011*"seat" + 0.010*"class" + 0.007*"food" + 0.006*"seats" + '
#   '0.006*"business" + 0.006*"economy" + 0.006*"time" + 0.005*"verified" + '
#   '0.005*"vancouver" + 0.005*"get"'),
#  (4,
#   '0.010*"class" + 0.009*"time" + 0.009*"good" + 0.008*"food" + '
#   '0.007*"economy" + 0.007*"crew" + 0.006*"verified" + 0.006*"business" + '
#   '0.006*"july" + 0.005*"flights"')]
#
#
# nan :
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-84ed1ec1df9a> in <module>
#       3     temp_df = df.loc[df['year_flown'] == year]
#       4     print(year, ":")
# ----> 5     topic_generator(temp_df, 5)
#       6     print('\n')
#
# <ipython-input-18-7bb52c958a15> in topic_generator(dfcol, num_topics)
#      10     # print(corpus[:1][0][:30])
#      11
# ---> 12     lda_model = gensim.models.LdaMulticore(corpus=corpus, id2word=id2word, num_topics=num_topics)
#      13     pprint(lda_model.print_topics())
#      14     doc_lda = lda_model[corpus]
#
# ~\anaconda3\lib\site-packages\gensim\models\ldamulticore.py in __init__(self, corpus, num_topics, id2word, workers, chunksize, passes, batch, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, random_state, minimum_probability, minimum_phi_value, per_word_topics, dtype)
#     177             raise NotImplementedError("auto-tuning alpha not implemented in multicore LDA; use plain LdaModel.")
#     178
# --> 179         super(LdaMulticore, self).__init__(
#     180             corpus=corpus, num_topics=num_topics,
#     181             id2word=id2word, chunksize=chunksize, passes=passes, alpha=alpha, eta=eta,
#
# ~\anaconda3\lib\site-packages\gensim\models\ldamodel.py in __init__(self, corpus, num_topics, id2word, distributed, chunksize, passes, update_every, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, minimum_probability, random_state, ns_conf, minimum_phi_value, per_word_topics, callbacks, dtype)
#     442
#     443         if self.num_terms == 0:
# --> 444             raise ValueError("cannot compute LDA over an empty collection (no terms)")
#     445
#     446         self.distributed = bool(distributed)
#
# ValueError: cannot compute LDA over an empty collection (no terms)

# %% [markdown]
# ### Analysis and Insights
